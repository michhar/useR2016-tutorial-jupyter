# %% [markdown]
# # Presentations using Jupyter Notebooks
#
# You can create slide presentation using Jupyter.

# %% [markdown]
# # Normal slide
#
# Any slide can contain code, markdown or plots

# %%
rnorm(10)
# Out:
#  [1]  1.32901454 -0.68516852 -2.27836692 -1.45115998 -0.01146199 -1.63963429
#  [7] -1.09716370 -0.11748713 -0.73642246  0.71344551

# %%
# These are my notes

# %% [markdown]
# # Section
#
# To create a new section, use Slide type "Slide"

# %% [markdown]
# ## Sub-slide
#
# To create slides in a section, use slide type "Sub-Slide"

# %%
options(repr.plot.width=4, repr.plot.height=3)
plot(1:10)
# Out:
# plot without title

# %% [markdown]
# # Navigation using keyboard shortcuts
#
# Use:
#
# * Left and right keys to navigate between slides
# * Use page up and page down to navigate between sub-slides
