# %% [markdown]
# # Presentations using Jupyter Notebooks
#
# You can create slide presentation using Jupyter.

# %% [markdown]
# # Normal slide
#
# Any slide can contain code, markdown or plots

# %%
rnorm(10)
# Out:
#  [1] -0.602762507  0.605207964  1.103987305  0.851865553 -0.001235458
#  [6]  0.702934150  1.866920304  0.616654273 -1.048140884  0.826297899

# %%
# These are my notes

# %% [markdown]
# # Overview mode
#
# ![Reveal shortcuts](imgs-reveal/overview.png)

# %% [markdown]
# # Section
#
# To create a new section, use Slide type "Slide"
#
# **To navigate to the sub-slide, press [Page down]**

# %% [markdown]
# ## Sub-slide
#
# To create slides in a section, use slide type "Sub-Slide"

# %%
options(repr.plot.width=4, repr.plot.height=3)
plot(1:10)
# Out:
# plot without title

# %% [markdown]
# # Navigation using keyboard shortcuts
#
#
#
# ![Reveal shortcuts](imgs-reveal/shortcuts.png)
